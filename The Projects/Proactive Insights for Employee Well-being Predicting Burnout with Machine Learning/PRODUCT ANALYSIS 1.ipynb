# %% [markdown]
# PRODUCT ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create sample product dataset
np.random.seed(42)

data = {
    'product_id': range(1, 21),
    'product_name': ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones',
                     'USB Cable', 'Desk', 'Chair', 'Webcam', 'Microphone',
                     'Speaker', 'External SSD', 'Tablet', 'Phone', 'Charger',
                     'Screen Protector', 'Phone Case', 'USB Hub', 'HDMI Cable', 'Stand'],
    'category': ['Electronics', 'Accessories', 'Accessories', 'Electronics', 'Audio',
                 'Cables', 'Furniture', 'Furniture', 'Electronics', 'Audio',
                 'Audio', 'Storage', 'Electronics', 'Electronics', 'Accessories',
                 'Accessories', 'Accessories', 'Cables', 'Cables', 'Accessories'],
    'price': np.random.randint(10, 1500, 20),
    'quantity_sold': np.random.randint(5, 500, 20),
    'rating': np.round(np.random.uniform(3.5, 5.0, 20), 1)
}

df = pd.DataFrame(data)
print(df)
# Out:
#     product_id      product_name     category  price  quantity_sold  rating
# 0            1            Laptop  Electronics   1136            496     4.0
# 1            2             Mouse  Accessories   1469            418     4.2
# 2            3          Keyboard  Accessories    870            298     4.7
# 3            4           Monitor  Electronics   1304            390     3.8
# 4            5        Headphones        Audio   1140            196     4.3
# 5            6         USB Cable       Cables   1105            448     4.4
# 6            7              Desk    Furniture   1054            281     3.6
# 7            8             Chair    Furniture    131            165     4.4
# 8            9            Webcam  Electronics    476            464     3.8
# 9           10        Microphone        Audio   1248            318     3.6
# 10          11           Speaker        Audio    340             26     4.9
# 11          12      External SSD      Storage   1492            257     4.9
# 12          13            Tablet  Electronics     97            240     4.7
# 13          14             Phone  Electronics   1406            349     4.0
# 14          15           Charger  Accessories   1133             53     3.6
# 15          16  Screen Protector  Accessories    881            479     4.5
# 16          17        Phone Case  Accessories    140             63     4.2
# 17          18           USB Hub       Cables   1342            174     3.7
# 18          19        HDMI Cable       Cables    779            480     4.2
# 19          20             Stand  Accessories    353            192     3.6

# %%
plt.bar(df['product_name'], df['quantity_sold'])

plt.xlabel('Product Name')  
plt.ylabel('Quantity Sold')
plt.title('Quantity Sold per Product')  
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
